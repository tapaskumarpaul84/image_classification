# %% [markdown]
# <a href="https://colab.research.google.com/github/tapaskumarpaul84/image_classification/blob/main/Test_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
trained_model=tf.keras.models.load_model("/content/drive/MyDrive/Colab Notebooks/george_mobilenetV2.h5")

# %%
def process_image(path):
  frame1=cv2.imread(path)
  final_image1=cv2.resize(frame1,(224,224))
  final_image1=np.expand_dims(final_image1,axis=0)
  plt.imshow(cv2.cvtColor(frame1,cv2.COLOR_BGR2RGB))
  return final_image1

# %%
def class_prediction(path):
  final_process_image=process_image(path)
  predictions=trained_model.predict(final_process_image)
  prediction_score=predictions[0][0]
  print(prediction_score)
  if prediction_score<0.5:
    category='George'
  else:
    category='no_george'
  #print(category)
  return category

# %%
category=class_prediction('/content/drive/MyDrive/image_data/no_george/no_george_1072.jpg')
# Out:
# 1/1 [==============================] - 0s 193ms/step
# 0.99967754

# %%
print(category)
# Out:
# no_george

# %%
category=class_prediction('/content/drive/MyDrive/image_data/george/george_1319.jpg')
# Out:
# 1/1 [==============================] - 0s 129ms/step
# 5.542699e-06

# %%
print(category)
# Out:
# George
